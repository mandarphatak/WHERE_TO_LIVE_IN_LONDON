# %%
import pandas as pd
from geopy.geocoders import GoogleV3
import geopy.distance
import googlemaps
import matplotlib.pyplot as plt

# %%
tube_data = pd.read_csv("london_stations_zones.csv")

# %%
tube_data.head()
# Out:
#    Unnamed: 0                               Station Local authority  \
# 0           0        Abbey Wood station, London, UK       Greenwich
# 1           1     Acton Central station, London, UK          Ealing
# 2           2   Acton Main Line station, London, UK          Ealing
# 3           3       Albany Park station, London, UK          Bexley
# 4           4  Alexandra Palace station, London, UK        Haringey
#
#           Managed by Stationcode Farezone Yearopened Category  \
# 0     Elizabeth line         ABW        4       1849        C
# 1  London Overground         ACC        3       1853        D
# 2     Elizabeth line         AML        3       1868        E
# 3       Southeastern         AYP        5       1935        D
# 4     Great Northern         AAP        3       1873        D
#
#                                          Coordinates
# 0  .mw-parser-output .geo-default,.mw-parser-outp...
# 1        51°30′32″N 0°15′48″W﻿ / ﻿51.5088°N 0.2634°W
# ...

# %%
API = 'AIzaSyB7GwqGUaePQCABdB2DyLJCs1qcC7yaSoM'

geolocator = GoogleV3(api_key=API)

print(type(geolocator))
# Out:
# <class 'geopy.geocoders.google.GoogleV3'>

# %%
tube_data.head()
# Out:
#    Unnamed: 0                               Station Local authority  \
# 0           0        Abbey Wood station, London, UK       Greenwich
# 1           1     Acton Central station, London, UK          Ealing
# 2           2   Acton Main Line station, London, UK          Ealing
# 3           3       Albany Park station, London, UK          Bexley
# 4           4  Alexandra Palace station, London, UK        Haringey
#
#           Managed by Stationcode Farezone Yearopened Category  \
# 0     Elizabeth line         ABW        4       1849        C
# 1  London Overground         ACC        3       1853        D
# 2     Elizabeth line         AML        3       1868        E
# 3       Southeastern         AYP        5       1935        D
# 4     Great Northern         AAP        3       1873        D
#
#                                          Coordinates
# 0  .mw-parser-output .geo-default,.mw-parser-outp...
# 1        51°30′32″N 0°15′48″W﻿ / ﻿51.5088°N 0.2634°W
# ...

# %%
lat = list()
long = list()
names = list()
for abc in tube_data.Station:
    print(abc)
    try:
        x = geolocator.geocode(abc)
        #print(x)
        y = x.longitude
        print(y)
        long.append(y)
        print(z)
        z = x.latitude
        lat.append(z)
    except:
        print("error")
        lat.append ('error')
        long.append('error')
        
tube_data["Latitude"] = lat
tube_data["longitude"] = long
# Out:
# Abbey Wood station, London, UK
# error
# Acton Central station, London, UK
# error
# Acton Main Line station, London, UK
# error
# Albany Park station, London, UK
# error
# Alexandra Palace station, London, UK
# error
# Amersham station, London, UK
# error
# Anerley station, London, UK
# error
# Balham station, London, UK
# error
# Banstead station, London, UK
# error
# Barking station, London, UK
# error
# Barking Riverside station, London, UK
# error
# Barnehurst station, London, UK
# error
# Barnes station, London, UK
# error
# Barnes Bridge station, London, UK
# error
# Battersea Park station, London, UK
# error
# Beckenham Hill station, London, UK
# error
# Beckenham Junction station, London, UK
# error
# Bellingham station, London, UK
# error
# Belmont station, London, UK
# error
# Belvedere station, London, UK
# error
# Berrylands station, London, UK
# error
# Bethnal Green station, London, UK
# error
# Bexley station, London, UK
# error
# Bexleyheath station, London, UK
# ...

# %%
tube_data
# Out:
#      Unnamed: 0                                Station Local authority  \
# 0             0         Abbey Wood station, London, UK       Greenwich
# 1             1      Acton Central station, London, UK          Ealing
# 2             2    Acton Main Line station, London, UK          Ealing
# 3             3        Albany Park station, London, UK          Bexley
# 4             4   Alexandra Palace station, London, UK        Haringey
# ..          ...                                    ...             ...
# 369         369        Wood Street station, London, UK  Waltham Forest
# 370         370           Woolwich station, London, UK       Greenwich
# 371         371   Woolwich Arsenal station, London, UK       Greenwich
# 372         372  Woolwich Dockyard station, London, UK       Greenwich
# 373         373     Worcester Park station, London, UK          Sutton
#
#                 Managed by Stationcode Farezone Yearopened  Category  \
# ...

# %%
#This code block is to test whether the API key is working.

name = 'Abbey Woodstation, London, UK'
location = geolocator.geocode(name)

print(location.address)
print(location.latitude, location.longitude)
# Out:
# ---------------------------------------------------------------------------
# GeocoderQueryError                        Traceback (most recent call last)
# Input In [25], in <cell line: 4>()
#       1 #This code block is to test whether the API key is working.
#       3 name = 'Abbey Woodstation, London, UK'
# ----> 4 location = geolocator.geocode(name)
#       6 print(location.address)
#       7 print(location.latitude, location.longitude)
#
# File /Volumes/cerebellum/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/google.py:270, in GoogleV3.geocode(self, query, exactly_one, timeout, bounds, region, components, place_id, language, sensor)
#     268 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     269 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 270 return self._call_geocoder(url, callback, timeout=timeout)
#
# ...

# %%
tube_data.head()
# Out:
#    Unnamed: 0                               Station Local authority  \
# 0           0        Abbey Wood station, London, UK       Greenwich
# 1           1     Acton Central station, London, UK          Ealing
# 2           2   Acton Main Line station, London, UK          Ealing
# 3           3       Albany Park station, London, UK          Bexley
# 4           4  Alexandra Palace station, London, UK        Haringey
#
#           Managed by Stationcode Farezone Yearopened Category  \
# 0     Elizabeth line         ABW        4       1849        C
# 1  London Overground         ACC        3       1853        D
# 2     Elizabeth line         AML        3       1868        E
# 3       Southeastern         AYP        5       1935        D
# 4     Great Northern         AAP        3       1873        D
#
#                                          Coordinates Latitude longitude
# 0  .mw-parser-output .geo-default,.mw-parser-outp...    error     error
# ...

# %%
tube_data.to_csv('tube_data_latlong.csv')

# %%
plt.scatter(lat, long)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 plt.scatter(lat, long)
#
# File /Volumes/cerebellum/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2810         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# ...
